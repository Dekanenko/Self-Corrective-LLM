# %%
import json
import random
import sys
import os

# Add the project root directory to the Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../../..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.agents.math_qa_correction_agent import MathQACorrectionAgent
random.seed(2)

# %%
with open(f"../../../dataset/raw_model_responses/train/train_UMWP.json", "r") as f:
    json_data = json.load(f)

# %%
index = 32

responses = json_data[index]["response"]

question = json_data[index]["additional_info"]["question"]
is_answerable = json_data[index]["additional_info"]["answerable"]
answer = json_data[index]["additional_info"]["answer"]

print(question)
print(is_answerable)
print(answer)
# Out:
#  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# True
# [15.0]

# %%
for i in range(len(responses)):
    print(responses[i])
    print("-" * 100)
# Out:
# 3 players remained. Each player had 5 lives.
#
# 3 * 5 = 15
#
# The total number of lives they had is 15.
# ----------------------------------------------------------------------------------------------------
# Step 1: Calculate the number of players left.
# 8 (initial players) - 5 (players who quit) = 3 players left
#
# Step 2: Determine the total number of lives.
# Each of the 3 players left had 5 lives.
# Total lives = 3 players * 5 lives/player = 15 lives
#
# The final answer is: $\boxed{15}$
# ----------------------------------------------------------------------------------------------------
# To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.
#
# Number of remaining players = 8 - 5 = 3
# Number of lives per player = 5
#
# Total lives = Number of remaining players × Number of lives per player
# = 3 × 5
# = 15
#
# The final answer is 15.
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the initial number of players and the number of players who quit.
# There were 8 friends initially, and 5 players quit.
#
# Step 2: Calculate the number of players who remained.
# 8 (initial players) - 5 (players who quit) = 3 players remained.
#
# Step 3: Determine the total number of lives remaining.
# Each of the 3 remaining players had 5 lives.
# Total lives = 3 (players) * 5 (lives per player) = 15 lives.
#
# The final answer is: oxed{15}$
# ----------------------------------------------------------------------------------------------------
# 3 friends were left playing, each with 5 lives.
#
# Step 1: Identify the number of friends left after some quit. 8 friends - 5 players quit = 3 friends left.
# Step 2: Determine the number of lives each friend had. Each friend had 5 lives.
# Step 3: Calculate the total number of lives. 3 friends * 5 lives per friend = 15 lives.
#
# The final answer is 15.
# ----------------------------------------------------------------------------------------------------
# Step 1: Determine the initial number of players and the number of players who quit.
# Initial players = 8
# Players who quit = 5
#
# Step 2: Calculate the number of players left after 5 players quit.
# Players left = Initial players - Players who quit
# Players left = 8 - 5
# Players left = 3
#
# Step 3: Calculate the total number of lives the remaining players had.
# Each player left had 5 lives.
# Total lives = Players left * Lives per player
# Total lives = 3 * 5
# Total lives = 15
#
# The final answer is: 15
# ----------------------------------------------------------------------------------------------------
# Given that there were 8 friends initially and 5 players quit, the number of players left is 8 - 5 = 3.
#
# Each of the 3 players left had 5 lives. To find the total number of lives, multiply the number of players by the number of lives each player had: 3 * 5 = 15.
#
# The total number of lives the players left had is 15.
# ----------------------------------------------------------------------------------------------------
# Let's analyze the given information:
#
# - Initially, there were 8 friends playing.
# - 5 players quit, so the number of players left is 8 - 5 = 3.
# - Each player left had 5 lives.
#
# To find the total number of lives, we multiply the number of players left by the number of lives each player had:
# 3 players * 5 lives/player = 15 lives
#
# The total number of lives they had is 15.
# ----------------------------------------------------------------------------------------------------
# Step 1: Understand the given information
# - There were 8 friends playing a video game online.
# - 5 players quit.
# - Each player left had 5 lives.
#
# Step 2: Determine the number of players left
# - Total players initially = 8
# - Players quit = 5
# - Players left = Total players initially - Players quit = 8 - 5 = 3
#
# Step 3: Calculate the total lives
# - Each player left had 5 lives.
# - Total lives = Number of players left * Lives per player = 3 * 5 = 15
#
# The final answer is 15.
# ----------------------------------------------------------------------------------------------------
# The problem states that there were 8 friends playing a video game online. Later, it mentions that 5 players quit, which implies that 3 players remained.
#
# Each of the 3 remaining players had 5 lives. To find the total number of lives, we multiply the number of players by the number of lives each player had.
#
# Total lives = Number of players * Lives per player
# Total lives = 3 * 5
# Total lives = 15
#
# The final answer is 15.
# ----------------------------------------------------------------------------------------------------

# %%
agent = MathQACorrectionAgent()

state = agent.model.invoke({
    "question": question,
    "answer": answer,
    "is_answerable": is_answerable,
    "responses": responses,
})
# Out:
# Response len: 10
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: 3 players remained. Each player had 5 lives.
#
# 3 * 5 = 15
#
# The total number of lives they had is 15.
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: Step 1: Calculate the number of players left.
# 8 (initial players) - 5 (players who quit) = 3 players left
#
# Step 2: Determine the total number of lives.
# Each of the 3 players left had 5 lives.
# Total lives = 3 players * 5 lives/player = 15 lives
#
# The final answer is: $\boxed{15}$
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.
#
# Number of remaining players = 8 - 5 = 3
# Number of lives per player = 5
#
# Total lives = Number of remaining players × Number of lives per player
# = 3 × 5
# = 15
#
# The final answer is 15.
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: Step 1: Identify the initial number of players and the number of players who quit.
# There were 8 friends initially, and 5 players quit.
#
# Step 2: Calculate the number of players who remained.
# 8 (initial players) - 5 (players who quit) = 3 players remained.
#
# Step 3: Determine the total number of lives remaining.
# Each of the 3 remaining players had 5 lives.
# Total lives = 3 (players) * 5 (lives per player) = 15 lives.
#
# The final answer is: oxed{15}$
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: 3 friends were left playing, each with 5 lives.
#
# Step 1: Identify the number of friends left after some quit. 8 friends - 5 players quit = 3 friends left.
# Step 2: Determine the number of lives each friend had. Each friend had 5 lives.
# Step 3: Calculate the total number of lives. 3 friends * 5 lives per friend = 15 lives.
#
# The final answer is 15.
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: Step 1: Determine the initial number of players and the number of players who quit.
# Initial players = 8
# Players who quit = 5
#
# Step 2: Calculate the number of players left after 5 players quit.
# Players left = Initial players - Players who quit
# Players left = 8 - 5
# Players left = 3
#
# Step 3: Calculate the total number of lives the remaining players had.
# Each player left had 5 lives.
# Total lives = Players left * Lives per player
# Total lives = 3 * 5
# Total lives = 15
#
# The final answer is: 15
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: Given that there were 8 friends initially and 5 players quit, the number of players left is 8 - 5 = 3.
#
# Each of the 3 players left had 5 lives. To find the total number of lives, multiply the number of players by the number of lives each player had: 3 * 5 = 15.
#
# The total number of lives the players left had is 15.
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# You are an expert AI Math Grader and Logic Verifier. Your sole function is to evaluate a `Response to Evaluate` for a given math `Question` and `Correct Answer`, based on pure mathematical and logical principles.
#
# # Core Principles
# 1. **The `Correct Answer` is the Ultimate Truth**: The `Correct Answer` is your infallible guide and the definitive interpretation of the `Question`. If a `Question` seems ambiguous, the `Correct Answer` resolves that ambiguity. Your evaluation MUST align with the logic that produces the `Correct Answer`.
# 2. **Mathematical and Logical Rigor**: Your primary focus is on correctness. This includes both the final numerical answer and the logical validity of every step in the reasoning. A correct final answer derived from flawed logic is a critical error.
# 3. **The Question is Inviolable**: The `Question` and `Correct Answer` are the absolute source of truth. You MUST NOT reinterpret the question or assume a different intent. Your sole task is to verify if the `Response to Evaluate` correctly solves the exact question asked.
# 4. **Tolerate Methodological Differences**: Do not penalize responses for using a different but mathematically sound method to arrive at the correct answer. Verbosity or stylistic phrasing is not an error if the underlying math and logic are correct.
# 5. **Precision and Objectivity**: Every identified error must be a concrete, verifiable flaw in calculation, logic, or explanation. Your output must be a structured list with no conversational filler.
#
# # Inputs
# **Question**:  There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total?
# **Correct Answer**: [15.0]
# **Response to Evaluate**: Let's analyze the given information:
#
# - Initially, there were 8 friends playing.
# - 5 players quit, so the number of players left is 8 - 5 = 3.
# - Each player left had 5 lives.
#
# To find the total number of lives, we multiply the number of players left by the number of lives each player had:
# 3 players * 5 lives/player = 15 lives
#
# The total number of lives they had is 15.
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# ...
# **Correct Answer**: [15.0]
# **Response to Evaluate**: The problem states that there were 8 friends playing a video game online. Later, it mentions that 5 players quit, which implies that 3 players remained.
#
# Each of the 3 remaining players had 5 lives. To find the total number of lives, we multiply the number of players by the number of lives each player had.
#
# Total lives = Number of players * Lives per player
# Total lives = 3 * 5
# Total lives = 15
#
# The final answer is 15.
#
# # Instructions
# 1. **Top Priority - The Unanswerable Question Rule**: First, check if the `Correct Answer` indicates no solution exists (e.g., it is empty, or states 'no solution'). If so, and the `Response to Evaluate` provides a definite answer, this is a fundamental failure. You MUST report **only one error** for this case and then stop your analysis. The error should be:
#    - `description`: "Provided a numerical answer when no solution exists."
#    - `location`: The entire text of the `Response to Evaluate`.
#    - `correction`: `DELETE: "[The entire text of the response]"`
# `ADD: "No solution exists."`
# 2. **Analyze**: Carefully review the `Question`, `Correct Answer`, and the entire `Response to Evaluate`, including the reasoning and final answer.
# 3. **Identify Flaws**: Pinpoint all discrepancies between the `Response to Evaluate` and the `Correct Answer`. Systematically check for:
#    - **Misinterpretation of the Question**: Does the response solve a different problem than the one asked? This is a critical error.
#    - **Calculation Errors**: Incorrect arithmetic operations (e.g., 2+2=5).
#    - **Logical Fallacies**: Flaws in the reasoning or incorrect application of mathematical theorems/properties.
#    - **Final Answer Mismatch**: The final result does not match the `Correct Answer`.
#    - **Grammatical Errors**: Mistakes in the explanation that obscure the mathematical meaning.
# 4. **Structure Errors**: For each substantive flaw found, you must define the following three fields with surgical precision:
#    - `description`: A concise, objective explanation of *why* it's an error.
#    - `location`: The *exact* substring from the `Response to Evaluate` that contains the error. This must be a verbatim quote.
#    - `correction`: A clear, actionable plan to fix the error. By following the plan, the response must become mathematically correct. You MUST use the following format:
#        `DELETE: "text to delete"`
#        `ADD: "text to add"`
#        - The `DELETE` part must contain text to be removed. If the fix is only an addition, do not include `DELETE` part.
#        - The `ADD` part must contain the text that should be inserted. If the fix is only a deletion, do not include `ADD` part.
#        - The text for `DELETE` and `ADD` must be whole words, numbers, or phrases, not partial words
#        **CRITICAL**: The text in `ADD` cannot be identical to the text in `DELETE`. A correction must create a meaningful change. If you find no change is needed, it is not an error.
#
# # Output Requirements
# 1. You MUST produce a list of structured errors. Each error must be unique.
# 2. If the response is completely correct according to all rules, you MUST return an empty list: `[]`.
# 3. Do not create more than 5 errors!
# 4. Do not include any headers, comments, or other text, except for the JSON output.
# 5. Strictly follow the format instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Error": {"description": "A model to represent an error found in a response.", "properties": {"description": {"description": "The error found in the response.", "title": "Description", "type": "string"}, "location": {"description": "The location of the error in the response.", "title": "Location", "type": "string"}, "correction": {"description": "Explanation on how to correct the error.", "title": "Correction", "type": "string"}}, "required": ["description", "location", "correction"], "title": "Error", "type": "object"}}, "description": "A model to hold a list of errors found in a response.", "properties": {"errors": {"default": [], "description": "A list of errors found in the response.", "items": {"$ref": "#/$defs/Error"}, "title": "Errors", "type": "array"}}}
# ```
#
# List of Errors:
# 2025-08-06 19:41:33.058 | INFO     | src.agents.math_qa_correction_agent:check_for_errors:91 - Errors: [[{'description': 'The question asks about the number of lives the players who quit had, but the response calculates the number of lives the players who remained had.', 'location': '3 players remained. Each player had 5 lives.\n\n3 * 5 = 15\n\nThe total number of lives they had is 15.', 'correction': 'DELETE: "3 players remained. Each player had 5 lives.\\n\\n3 * 5 = 15\\n\\nThe total number of lives they had is 15."\nADD: "5 players quit. Each player had 5 lives.\\n\\n5 * 5 = 25\\n\\nThe total number of lives they had is 25."'}], [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who remained.', 'location': 'Step 1: Calculate the number of players left.\n8 (initial players) - 5 (players who quit) = 3 players left\n\nStep 2: Determine the total number of lives.\nEach of the 3 players left had 5 lives.\nTotal lives = 3 players * 5 lives/player = 15 lives', 'correction': 'DELETE: "Step 1: Calculate the number of players left.\n8 (initial players) - 5 (players who quit) = 3 players left\n\nStep 2: Determine the total number of lives.\nEach of the 3 players left had 5 lives.\nTotal lives = 3 players * 5 lives/player = 15 lives"\nADD: "Step 1: Calculate the total number of lives.\n5 players * 5 lives/player = 25 lives"'}, {'description': 'The final answer is incorrect because the response misinterprets the question.', 'location': 'The final answer is: $\\boxed{15}$', 'correction': 'DELETE: "The final answer is: $\\boxed{15}$"\nADD: "The final answer is: $\\boxed{25}$"'}], [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.', 'location': 'To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.', 'correction': 'DELETE: "remaining players"\nADD: "players who quit"'}, {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of remaining players.', 'location': 'Number of remaining players = 8 - 5 = 3', 'correction': 'DELETE: "remaining players = 8 - 5 = 3"\nADD: "players who quit = 5"'}, {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.', 'location': 'Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15', 'correction': 'DELETE: "Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15"\nADD: "Total lives = Number of players who quit * Number of lives per player\n= 5 * 5\n= 25"'}, {'description': 'The final answer is incorrect because the response misinterprets the question.', 'location': 'The final answer is 15.', 'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}], [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the players who remained.', 'location': 'Step 3: Determine the total number of lives remaining.\nEach of the 3 remaining players had 5 lives.\nTotal lives = 3 (players) * 5 (lives per player) = 15 lives.', 'correction': 'DELETE: "Step 3: Determine the total number of lives remaining.\\nEach of the 3 remaining players had 5 lives.\\nTotal lives = 3 (players) * 5 (lives per player) = 15 lives."\nADD: "Step 3: Determine the total number of lives of the players who quit.\\nEach of the 5 players who quit had 5 lives.\\nTotal lives = 5 (players) * 5 (lives per player) = 25 lives."'}, {'description': 'The final answer is incorrect because it calculates the lives of the remaining players instead of the players who quit.', 'location': 'The final answer is: $\x08oxed{15} ...
# 2025-08-06 19:41:33.059 | INFO     | src.agents.math_qa_correction_agent:check_for_errors:92 - Wrong responses: 10
# 2025-08-06 19:41:33.060 | INFO     | src.agents.math_qa_correction_agent:get_errors_to_correct:120 - Errors to correct: ([{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.', 'location': 'To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.', 'correction': 'DELETE: "remaining players"\nADD: "players who quit"'}, {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of remaining players.', 'location': 'Number of remaining players = 8 - 5 = 3', 'correction': 'DELETE: "remaining players = 8 - 5 = 3"\nADD: "players who quit = 5"'}, {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.', 'location': 'Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15', 'correction': 'DELETE: "Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15"\nADD: "Total lives = Number of players who quit * Number of lives per player\n= 5 * 5\n= 25"'}, {'description': 'The final answer is incorrect because the response misinterprets the question.', 'location': 'The final answer is 15.', 'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}], [{'description': 'The question asks how many lives the players who quit had in total, but the response calculates the number of lives the players who remained had.', 'location': 'Each player left had 5 lives.', 'correction': 'DELETE: "Each player left had 5 lives."\nADD: "Each player who quit had 5 lives."'}, {'description': 'The response calculates the number of lives the players who remained had, but it should calculate the number of lives the players who quit had.', 'location': 'To find the total number of lives, we multiply the number of players left by the number of lives each player had:\n3 players * 5 lives/player = 15 lives', 'correction': 'DELETE: "To find the total number of lives, we multiply the number of players left by the number of lives each player had:\\n3 players * 5 lives/player = 15 lives"\nADD: "To find the total number of lives, we multiply the number of players who quit by the number of lives each player had:\\n5 players * 5 lives/player = 25 lives"'}, {'description': 'The response calculates the number of lives the players who remained had, but it should calculate the number of lives the players who quit had.', 'location': 'The total number of lives they had is 15.', 'correction': 'DELETE: "The total number of lives they had is 15."\nADD: "The total number of lives they had is 25."'}], [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who are left.', 'location': 'Step 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3', 'correction': 'DELETE: "Step 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3"\nADD: "Step 2: Determine the number of players who quit\n- Players who quit = 5"'}, {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who are left.', 'location': 'Step 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15', 'correction': 'DELETE: "Step 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15"\nADD: "Step 3: Calculate the total lives of the player ...
# 2025-08-06 19:41:33.060 | INFO     | src.agents.math_qa_correction_agent:get_errors_to_correct:121 - Responses to correct: ('To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.\n\nNumber of remaining players = 8 - 5 = 3\nNumber of lives per player = 5\n\nTotal lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15\n\nThe final answer is 15.', "Let's analyze the given information:\n\n- Initially, there were 8 friends playing.\n- 5 players quit, so the number of players left is 8 - 5 = 3.\n- Each player left had 5 lives.\n\nTo find the total number of lives, we multiply the number of players left by the number of lives each player had:\n3 players * 5 lives/player = 15 lives\n\nThe total number of lives they had is 15.", 'Step 1: Understand the given information\n- There were 8 friends playing a video game online.\n- 5 players quit.\n- Each player left had 5 lives.\n\nStep 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3\n\nStep 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15\n\nThe final answer is 15.')
# 2025-08-06 19:41:34.686 | INFO     | src.agents.math_qa_correction_agent:correct_response:157 - Corrected responses: ['To find the total number of lives, we need to multiply the number of remaining players<DEL_W> players who quit by the number of lives each player had.\n\nNumber of remaining players<DEL_S> players who quit = 5\nNumber of lives per player = 5\n\nTotal lives = Number of remaining players<DEL_W> players who quit × Number of lives per player\n= 3<DEL_W> 5 × 5\n= 15<DEL_W> 25\n\nThe final answer is 15.<DEL_W> 25.', "Let's analyze the given information:\n\n- Initially, there were 8 friends playing.\n- 5 players quit, so the number of players left is 8 - 5 = 3.\n- Each player left<DEL_W> who quit had 5 lives.\n\nTo find the total number of lives, we multiply the number of players left<DEL_W> who quit by the number of lives each player had:\n3<DEL_W> 5 players * 5 lives/player = 15<DEL_W> 25 lives\n\nThe total number of lives they had is 15<DEL_W> 25.", 'Step 1: Understand the given information\n- There were 8 friends playing a video game online.\n- 5 players quit.\n- Each player left had 5 lives.\n\nStep 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3<DEL_S>\n\nStep 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15<DEL_S> Step 3: Calculate the total lives of the players who quit\n- Each player who quit had 5 lives.\n- Total lives = Number of players who quit * Lives per player = 5 * 5 = 25\n\nThe final answer is 15.<DEL_S> The final answer is 25.']
# 2025-08-06 19:41:53.662 | INFO     | src.agents.math_qa_correction_agent:verify_corrected_response:190 - Verified responses: ['False', 'False', 'False']

# %%
state
# Out:
# {'question': ' There were 8 friends playing a video game online when 5 players quit. If each player left had 5 lives, how many lives did they have total? ',
#  'answer': [15.0],
#  'is_answerable': True,
#  'responses': ['3 players remained. Each player had 5 lives. \n\n3 * 5 = 15\n\nThe total number of lives they had is 15.',
#   'Step 1: Calculate the number of players left.\n8 (initial players) - 5 (players who quit) = 3 players left\n\nStep 2: Determine the total number of lives.\nEach of the 3 players left had 5 lives.\nTotal lives = 3 players * 5 lives/player = 15 lives\n\nThe final answer is: $\\boxed{15}$',
#   'To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.\n\nNumber of remaining players = 8 - 5 = 3\nNumber of lives per player = 5\n\nTotal lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15\n\nThe final answer is 15.',
#   'Step 1: Identify the initial number of players and the number of players who quit.\nThere were 8 friends initially, and 5 players quit.\n\nStep 2: Calculate the number of players who remained.\n8 (initial players) - 5 (players who quit) = 3 players remained.\n\nStep 3: Determine the total number of lives remaining.\nEach of the 3 remaining players had 5 lives.\nTotal lives = 3 (players) * 5 (lives per player) = 15 lives.\n\nThe final answer is: $\x08oxed{15}$',
#   '3 friends were left playing, each with 5 lives.\n\nStep 1: Identify the number of friends left after some quit. 8 friends - 5 players quit = 3 friends left.\nStep 2: Determine the number of lives each friend had. Each friend had 5 lives.\nStep 3: Calculate the total number of lives. 3 friends * 5 lives per friend = 15 lives.\n\nThe final answer is 15.',
#   'Step 1: Determine the initial number of players and the number of players who quit.\nInitial players = 8\nPlayers who quit = 5\n\nStep 2: Calculate the number of players left after 5 players quit.\nPlayers left = Initial players - Players who quit\nPlayers left = 8 - 5\nPlayers left = 3\n\nStep 3: Calculate the total number of lives the remaining players had.\nEach player left had 5 lives.\nTotal lives = Players left * Lives per player\nTotal lives = 3 * 5\nTotal lives = 15\n\nThe final answer is: 15',
#   'Given that there were 8 friends initially and 5 players quit, the number of players left is 8 - 5 = 3.\n\nEach of the 3 players left had 5 lives. To find the total number of lives, multiply the number of players by the number of lives each player had: 3 * 5 = 15.\n\nThe total number of lives the players left had is 15.',
#   "Let's analyze the given information:\n\n- Initially, there were 8 friends playing.\n- 5 players quit, so the number of players left is 8 - 5 = 3.\n- Each player left had 5 lives.\n\nTo find the total number of lives, we multiply the number of players left by the number of lives each player had:\n3 players * 5 lives/player = 15 lives\n\nThe total number of lives they had is 15.",
#   'Step 1: Understand the given information\n- There were 8 friends playing a video game online.\n- 5 players quit.\n- Each player left had 5 lives.\n\nStep 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3\n\nStep 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15\n\nThe final answer is 15.',
#   'The problem states that there were 8 friends playing a video game online. Later, it mentions that 5 players quit, which implies that 3 players remained. \n\nEach of the 3 remaining players had 5 lives. To find the total number of lives, we multiply the number of players by the number of lives each player had.\n\nTotal lives = Number of players * Lives per player\nTotal lives = 3 * 5\nTotal lives = 15\n\nThe final answer is 15.'],
#  'errors': [[{'description': 'The question asks about the number of lives the players who quit had, but the response calculates the number of lives the players who remained had.',
#     'location': '3 players remained. Each player had 5 lives.\n\n3 * 5 = 15\n\nThe total number of lives they had is 15.',
#     'correction': 'DELETE: "3 players remained. Each player had 5 lives.\\n\\n3 * 5 = 15\\n\\nThe total number of lives they had is 15."\nADD: "5 players quit. Each player had 5 lives.\\n\\n5 * 5 = 25\\n\\nThe total number of lives they had is 25."'}],
#   [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who remained.',
#     'location': 'Step 1: Calculate the number of players left.\n8 (initial players) - 5 (players who quit) = 3 players left\n\nStep 2: Determine the total number of lives.\nEach of the 3 players left had 5 lives.\nTotal lives = 3 players * 5 lives/player = 15 lives',
#     'correction': 'DELETE: "Step 1: Calculate the number of players left.\n8 (initial players) - 5 (players who quit) = 3 players left\n\nStep 2: Determine the total number of lives.\nEach of the 3 players left had 5 lives.\nTotal lives = 3 players * 5 lives/player = 15 lives"\nADD: "Step 1: Calculate the total number of lives.\n5 players * 5 lives/player = 25 lives"'},
#    {'description': 'The final answer is incorrect because the response misinterprets the question.',
#     'location': 'The final answer is: $\\boxed{15}$',
#     'correction': 'DELETE: "The final answer is: $\\boxed{15}$"\nADD: "The final answer is: $\\boxed{25}$"'}],
#   [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.',
#     'location': 'To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.',
#     'correction': 'DELETE: "remaining players"\nADD: "players who quit"'},
#    {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of remaining players.',
#     'location': 'Number of remaining players = 8 - 5 = 3',
#     'correction': 'DELETE: "remaining players = 8 - 5 = 3"\nADD: "players who quit = 5"'},
#    {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.',
#     'location': 'Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15',
#     'correction': 'DELETE: "Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15"\nADD: "Total lives = Number of players who quit * Number of lives per player\n= 5 * 5\n= 25"'},
#    {'description': 'The final answer is incorrect because the response misinterprets the question.',
#     'location': 'The final answer is 15.',
#     'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}],
#   [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the players who remained.',
#     'location': 'Step 3: Determine the total number of lives remaining.\nEach of the 3 remaining players had 5 lives.\nTotal lives = 3 (players) * 5 (lives per player) = 15 lives.',
#     'correction': 'DELETE: "Step 3: Determine the total number of lives remaining.\\nEach of the 3 remaining players had 5 lives.\\nTotal lives = 3 (players) * 5 (lives per player) = 15 lives."\nADD: "Step 3: Determine the total number of lives of the players who quit.\\nEach of the 5 players who quit had 5 lives.\\nTotal lives = 5 (players) * 5 (lives per player) = 25 lives."'},
#    {'description': 'The final answer is incorrect because it calculates the lives of the remaining players instead of the players who quit.',
#     'location': 'The final answer is: $\x08oxed{15}$',
#     'correction': 'DELETE: "The final answer is: $\x08oxed{15}$"\nADD: "The final answer is: $\x08oxed{25}$"'}],
#   [{'description': 'The question asks how many lives the players who quit had in total, but the response calculates the number of lives the players who remained had.',
#     'location': '3 friends were left playing, each with 5 lives.\n\nStep 1: Identify the number of friends left after some quit. 8 friends - 5 players quit = 3 friends left.\nStep 2: Determine the number of lives each friend had. Each friend had 5 lives.\nStep 3: Calculate the total number of lives. 3 friends * 5 lives per friend = 15 lives.',
#     'correction': 'DELETE: "3 friends were left playing, each with 5 lives.\\n\\nStep 1: Identify the number of friends left after some quit. 8 friends - 5 players quit = 3 friends left.\\nStep 2: Determine the number of lives each friend had. Each friend had 5 lives.\\nStep 3: Calculate the total number of lives. 3 friends * 5 lives per friend = 15 lives."\nADD: "5 players quit, each with 5 lives.\\n\\nStep 1: Identify the number of players who quit. 5 players quit.\nStep 2: Determine the number of lives each player had. Each player had 5 lives.\nStep 3: Calculate the total number of lives. 5 players * 5 lives per player = 25 lives."'},
#    {'description': 'The final answer does not match the correct answer. The response calculated the number of lives of the remaining players instead of the players who quit.',
#     'location': 'The final answer is 15.',
#     'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}],
#   [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the players who remained.',
#     'location': 'Step 3: Calculate the total number of lives the remaining players had.\nEach player left had 5 lives.\nTotal lives = Players left * Lives per player\nTotal lives = 3 * 5\nTotal lives = 15',
#     'correction': 'DELETE: "Step 3: Calculate the total number of lives the remaining players had.\\nEach player left had 5 lives.\\nTotal lives = Players left * Lives per player\\nTotal lives = 3 * 5\\nTotal lives = 15"\nADD: "Step 3: Calculate the total number of lives the players who quit had.\\nEach player who quit had 5 lives.\\nTotal lives = Players who quit * Lives per player\\nTotal lives = 5 * 5\\nTotal lives = 25"'},
#    {'description': 'The final answer is incorrect because it calculates the total number of lives of the players who remained instead of the players who quit.',
#     'location': 'The final answer is: 15',
#     'correction': 'DELETE: "The final answer is: 15"\nADD: "The final answer is: 25"'}],
#   [{'description': 'The question asks about the lives of the players who quit, but the response calculates the lives of the players who remained.',
#     'location': 'Given that there were 8 friends initially and 5 players quit, the number of players left is 8 - 5 = 3.\n\nEach of the 3 players left had 5 lives. To find the total number of lives, multiply the number of players by the number of lives each player had: 3 * 5 = 15.\n\nThe total number of lives the players left had is 15.',
#     'correction': 'DELETE: "Given that there were 8 friends initially and 5 players quit, the number of players left is 8 - 5 = 3.\\n\\nEach of the 3 players left had 5 lives. To find the total number of lives, multiply the number of players by the number of lives each player had: 3 * 5 = 15.\\n\\nThe total number of lives the players left had is 15."\nADD: "Given that 5 players quit and each player had 5 lives, the total number of lives they had is 5 * 5 = 25."'}],
#   [{'description': 'The question asks how many lives the players who quit had in total, but the response calculates the number of lives the players who remained had.',
#     'location': 'Each player left had 5 lives.',
#     'correction': 'DELETE: "Each player left had 5 lives."\nADD: "Each player who quit had 5 lives."'},
#    {'description': 'The response calculates the number of lives the players who remained had, but it should calculate the number of lives the players who quit had.',
#     'location': 'To find the total number of lives, we multiply the number of players left by the number of lives each player had:\n3 players * 5 lives/player = 15 lives',
#     'correction': 'DELETE: "To find the total number of lives, we multiply the number of players left by the number of lives each player had:\\n3 players * 5 lives/player = 15 lives"\nADD: "To find the total number of lives, we multiply the number of players who quit by the number of lives each player had:\\n5 players * 5 lives/player = 25 lives"'},
#    {'description': 'The response calculates the number of lives the players who remained had, but it should calculate the number of lives the players who quit had.',
#     'location': 'The total number of lives they had is 15.',
#     'correction': 'DELETE: "The total number of lives they had is 15."\nADD: "The total number of lives they had is 25."'}],
#   [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who are left.',
#     'location': 'Step 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3',
#     'correction': 'DELETE: "Step 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3"\nADD: "Step 2: Determine the number of players who quit\n- Players who quit = 5"'},
#    {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who are left.',
#     'location': 'Step 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15',
#     'correction': 'DELETE: "Step 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15"\nADD: "Step 3: Calculate the total lives of the players who quit\n- Each player who quit had 5 lives.\n- Total lives = Number of players who quit * Lives per player = 5 * 5 = 25"'},
#    {'description': 'The final answer is incorrect because it calculates the number of lives of the players who are left, not the players who quit.',
#     'location': 'The final answer is 15.',
#     'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}],
#   [{'description': 'The response misinterprets the question. The question asks how many lives the players who quit had in total, not how many lives the remaining players had.',
#     'location': 'The problem states that there were 8 friends playing a video game online. Later, it mentions that 5 players quit, which implies that 3 players remained.',
#     'correction': 'DELETE: "The problem states that there were 8 friends playing a video game online. Later, it mentions that 5 players quit, which implies that 3 players remained."\nADD: "The problem states that 5 players quit the game."'},
#    {'description': 'The response calculates the total lives of the remaining players instead of the players who quit.',
#     'location': 'Each of the 3 remaining players had 5 lives. To find the total number of lives, we multiply the number of players by the number of lives each player had.\n\nTotal lives = Number of players * Lives per player\nTotal lives = 3 * 5\nTotal lives = 15',
#     'correction': 'DELETE: "Each of the 3 remaining players had 5 lives. To find the total number of lives, we multiply the number of players by the number of lives each player had.\\n\\nTotal lives = Number of players * Lives per player\\nTotal lives = 3 * 5\\nTotal lives = 15"\nADD: "Each of the 5 players who quit had 5 lives. To find the total number of lives, we multiply the number of players who quit by the number of lives each player had.\\n\\nTotal lives = Number of players who quit * Lives per player\\nTotal lives = 5 * 5\\nTotal lives = 25"'},
#    {'description': 'The final answer is incorrect because it calculates the total lives of the remaining players instead of the players who quit.',
#     'location': 'The final answer is 15.',
#     'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}]],
#  'wrong_response_number': 10,
#  'responses_to_correct': ('To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.\n\nNumber of remaining players = 8 - 5 = 3\nNumber of lives per player = 5\n\nTotal lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15\n\nThe final answer is 15.',
#   "Let's analyze the given information:\n\n- Initially, there were 8 friends playing.\n- 5 players quit, so the number of players left is 8 - 5 = 3.\n- Each player left had 5 lives.\n\nTo find the total number of lives, we multiply the number of players left by the number of lives each player had:\n3 players * 5 lives/player = 15 lives\n\nThe total number of lives they had is 15.",
#   'Step 1: Understand the given information\n- There were 8 friends playing a video game online.\n- 5 players quit.\n- Each player left had 5 lives.\n\nStep 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3\n\nStep 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15\n\nThe final answer is 15.'),
#  'errors_to_correct': ([{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.',
#     'location': 'To find the total number of lives, we need to multiply the number of remaining players by the number of lives each player had.',
#     'correction': 'DELETE: "remaining players"\nADD: "players who quit"'},
#    {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of remaining players.',
#     'location': 'Number of remaining players = 8 - 5 = 3',
#     'correction': 'DELETE: "remaining players = 8 - 5 = 3"\nADD: "players who quit = 5"'},
#    {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the total number of lives of the remaining players.',
#     'location': 'Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15',
#     'correction': 'DELETE: "Total lives = Number of remaining players × Number of lives per player\n= 3 × 5\n= 15"\nADD: "Total lives = Number of players who quit * Number of lives per player\n= 5 * 5\n= 25"'},
#    {'description': 'The final answer is incorrect because the response misinterprets the question.',
#     'location': 'The final answer is 15.',
#     'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}],
#   [{'description': 'The question asks how many lives the players who quit had in total, but the response calculates the number of lives the players who remained had.',
#     'location': 'Each player left had 5 lives.',
#     'correction': 'DELETE: "Each player left had 5 lives."\nADD: "Each player who quit had 5 lives."'},
#    {'description': 'The response calculates the number of lives the players who remained had, but it should calculate the number of lives the players who quit had.',
#     'location': 'To find the total number of lives, we multiply the number of players left by the number of lives each player had:\n3 players * 5 lives/player = 15 lives',
#     'correction': 'DELETE: "To find the total number of lives, we multiply the number of players left by the number of lives each player had:\\n3 players * 5 lives/player = 15 lives"\nADD: "To find the total number of lives, we multiply the number of players who quit by the number of lives each player had:\\n5 players * 5 lives/player = 25 lives"'},
#    {'description': 'The response calculates the number of lives the players who remained had, but it should calculate the number of lives the players who quit had.',
#     'location': 'The total number of lives they had is 15.',
#     'correction': 'DELETE: "The total number of lives they had is 15."\nADD: "The total number of lives they had is 25."'}],
#   [{'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who are left.',
#     'location': 'Step 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3',
#     'correction': 'DELETE: "Step 2: Determine the number of players left\n- Total players initially = 8\n- Players quit = 5\n- Players left = Total players initially - Players quit = 8 - 5 = 3"\nADD: "Step 2: Determine the number of players who quit\n- Players who quit = 5"'},
#    {'description': 'The question asks for the total number of lives of the players who quit, but the response calculates the number of lives of the players who are left.',
#     'location': 'Step 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15',
#     'correction': 'DELETE: "Step 3: Calculate the total lives\n- Each player left had 5 lives.\n- Total lives = Number of players left * Lives per player = 3 * 5 = 15"\nADD: "Step 3: Calculate the total lives of the players who quit\n- Each player who quit had 5 lives.\n- Total lives = Number of players who quit * Lives per player = 5 * 5 = 25"'},
#    {'description': 'The final answer is incorrect because it calculates the number of lives of the players who are left, not the players who quit.',
#     'location': 'The final answer is 15.',
#     'correction': 'DELETE: "The final answer is 15."\nADD: "The final answer is 25."'}]),
#  'corrected_responses': [],
#  'verified_response_mask': [False, False, False]}
